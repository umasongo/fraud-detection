# %% [markdown]
# # Data preparation

# %%
#suppress warnings
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import GridSearchCV

# %%
SHEET_ID = '1pcmXXIryOc1hqpgFk3Tr3F3NaRjupklR9UtK7m0g-zA'
SHEET_NAME = 'fraud-sms-dataset'
url = f'https://docs.google.com/spreadsheets/d/{SHEET_ID}/gviz/tq?tqx=out:csv&sheet={SHEET_NAME}'

df = pd.read_csv(url, header=None)
df.columns = ["label","text"]
df.head()
# Out:
#   label                                               text
# 0  spam  Hello, invest 18,000/= and earn 5,400/= - 10,8...
# 1   ham  You have bought UGX 5,000 airtime. New MoMo ba...
# 2   ham  You have sent UGX 11000 to JUMA UTHMAN KIWALAB...
# 3   ham  Bundle loaded worth UGX 5,000/- . New balance:...
# 4   ham  You have received UGX 10000 from AMURU SSENTAM...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   915 non-null    object
#  1   text    915 non-null    object
# dtypes: object(2)
# memory usage: 14.4+ KB

# %% [markdown]
# ### Text Processing and Cleaning

# %%
df['label'] = df['label'].astype(str)
df['label'] = df['label'].str.strip()
df["label"].value_counts()
# Out:
# ham     803
# spam    112
# Name: label, dtype: int64

# %%
sns.set(rc={"figure.figsize":(8, 3)}) #width=8, height=3
sns.countplot(y='label', data=df).set(title='Spam vs Ham count');

# %% [markdown]
# #### Trim spaces and convert to lowercase

# %%
#Cast to string
df['text'] = df['text'].astype(str)
df['text'] = df['text'].str.strip().str.lower()

# %% [markdown]
# #### Expand contractions

# %%
import contractions
df['text'] = df['text'].apply(lambda x: contractions.fix(x))

# %% [markdown]
# #### Removing the punctuations

# %%
import string

# create function for punctuation removal:
def remove_punctuations(text):
    for char in string.punctuation:
        text = text.replace(char, '')
    return text

# apply the function:
df['text'] = df['text'].apply(remove_punctuations)

# %% [markdown]
# #### Removing the stopwords

# %%
# import list of stopwords:
from nltk.corpus import stopwords
stopwords = stopwords.words('english')

# add more words to stopwords list:
guided_list = ['winning', 'prize', 'invest']
stopwords.extend(guided_list)

# update column without the stopwords:
df['text'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in stopwords]))

# %% [markdown]
# #### Tokenize sentences

# %%
from nltk.tokenize import word_tokenize

#Create a tokenizer
def tokenize(column):
    tokens = word_tokenize(column)
    return [w for w in tokens if w.isalpha()] 

#Tokenize the text data
df['tokenized'] = df.apply(lambda x: tokenize(x['text']), axis=1)
df[['tokenized']].head()
# Out:
#                                            tokenized
# 0  [hello, earn, everyday, paid, via, mobile, mon...
# 1  [bought, ugx, airtime, new, momo, balance, ugx...
# 2  [sent, ugx, juma, uthman, kiwalabye, fee, reas...
# 3  [bundle, loaded, worth, ugx, new, balance, ugx...
# 4  [received, ugx, amuru, ssentamu, reason, mobil...

# %%
# Remove infrequent words and keep only words which are longer than 2 letters
df['text_string'] = df['tokenized'].apply(lambda x: ' '.join([item for item in x if len(item)>2]))

# Create a list of all words
all_words = ' '.join([word for word in df['text_string']])

# Tokenize all_words
tokenized_words = word_tokenize(all_words)

# %%
# Create a frequency distribution which records the number of times each word has occurred:
from nltk.probability import FreqDist

fdist = FreqDist(tokenized_words)
fdist
# Out:
# FreqDist({'ugx': 1021, 'dial': 282, 'money': 277, 'balance': 269, 'mtn': 251, 'mobile': 244, 'new': 197, 'limited': 192, 'bundle': 180, 'uganda': 177, ...})

# %%
# Use fdist dictionary to drop words which occur less than a certain amount of times (usually 3 or 4).
df['text_string_fdist'] = df['tokenized'].apply(lambda x: ' '.join([item for item in x if fdist[item] >= 1 ]))

# %% [markdown]
# #### Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
wordnet = WordNetLemmatizer()

df['lemmatized'] = df['text_string_fdist'].apply(wordnet.lemmatize)
df.head()
# Out:
#   label                                               text  \
# 0  spam  hello 18000 earn 5400 10800 everyday paid via ...
# 1   ham  bought ugx 5000 airtime new momo balance ugx 2...
# 2   ham  sent ugx 11000 juma uthman kiwalabye 256771838...
# 3   ham  bundle loaded worth ugx 5000 new balance ugx 6...
# 4   ham  received ugx 10000 amuru ssentamu 256771844720...
#
#                                            tokenized  \
# 0  [hello, earn, everyday, paid, via, mobile, mon...
# 1  [bought, ugx, airtime, new, momo, balance, ugx...
# 2  [sent, ugx, juma, uthman, kiwalabye, fee, reas...
# 3  [bundle, loaded, worth, ugx, new, balance, ugx...
# 4  [received, ugx, amuru, ssentamu, reason, mobil...
#
#                                          text_string  \
# 0  hello earn everyday paid via mobile money regi...
# 1  bought ugx airtime new momo balance ugx share ...
# 2  sent ugx juma uthman kiwalabye fee reason new ...
# 3  bundle loaded worth ugx new balance ugx transa...
# 4  received ugx amuru ssentamu reason mobile new ...
#
#                                    text_string_fdist  \
# 0  hello earn everyday paid via mobile money regi...
# 1  bought ugx airtime new momo balance ugx share ...
# 2  sent ugx juma uthman kiwalabye fee reason new ...
# 3  bundle loaded worth ugx new balance ugx transa...
# 4  received ugx amuru ssentamu reason mobile new ...
#
#                                           lemmatized
# 0  hello earn everyday paid via mobile money regi...
# 1  bought ugx airtime new momo balance ugx share ...
# 2  sent ugx juma uthman kiwalabye fee reason new ...
# 3  bundle loaded worth ugx new balance ugx transa...
# 4  received ugx amuru ssentamu reason mobile new ...

# %% [markdown]
# #### Word cloud

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

all_words_lem = ' '.join([word for word in df['lemmatized']])

wordcloud = WordCloud(width=800, 
                     height=300, 
                     random_state=2, 
                     max_font_size=100).generate(all_words_lem)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off');

# %% [markdown]
# ### Split data for classification

# %%
# Convert labeled data to encoded data
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

df['lemmatized_encd'] = le.fit_transform(df['lemmatized'])
#print('Text Encoded', df['lemmatized_encd'])

df['label_encd'] = le.fit_transform(df['label'])
#print('Label Encoded', df['label_encd'])

# Create feature set
#features = list(zip(text_encoded))

df.head()
# Out:
#   label                                               text  \
# 0  spam  hello 18000 earn 5400 10800 everyday paid via ...
# 1   ham  bought ugx 5000 airtime new momo balance ugx 2...
# 2   ham  sent ugx 11000 juma uthman kiwalabye 256771838...
# 3   ham  bundle loaded worth ugx 5000 new balance ugx 6...
# 4   ham  received ugx 10000 amuru ssentamu 256771844720...
#
#                                            tokenized  \
# 0  [hello, earn, everyday, paid, via, mobile, mon...
# 1  [bought, ugx, airtime, new, momo, balance, ugx...
# 2  [sent, ugx, juma, uthman, kiwalabye, fee, reas...
# 3  [bundle, loaded, worth, ugx, new, balance, ugx...
# 4  [received, ugx, amuru, ssentamu, reason, mobil...
#
#                                          text_string  \
# 0  hello earn everyday paid via mobile money regi...
# 1  bought ugx airtime new momo balance ugx share ...
# 2  sent ugx juma uthman kiwalabye fee reason new ...
# 3  bundle loaded worth ugx new balance ugx transa...
# 4  received ugx amuru ssentamu reason mobile new ...
#
#                                    text_string_fdist  \
# 0  hello earn everyday paid via mobile money regi...
# 1  bought ugx airtime new momo balance ugx share ...
# 2  sent ugx juma uthman kiwalabye fee reason new ...
# 3  bundle loaded worth ugx new balance ugx transa...
# 4  received ugx amuru ssentamu reason mobile new ...
#
#                                           lemmatized  lemmatized_encd  \
# 0  hello earn everyday paid via mobile money regi...              177
# 1  bought ugx airtime new momo balance ugx share ...               21
# 2  sent ugx juma uthman kiwalabye fee reason new ...              306
# 3  bundle loaded worth ugx new balance ugx transa...               25
# 4  received ugx amuru ssentamu reason mobile new ...              266
#
#    label_encd
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %%
# Split the data into training and testing set
# Create a stratified train/test split. 
# Test set will be 30% of the data and Training set 70%.
# Class distribution will be equal for train test and original data

from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.3, stratify=df.label_encd)

# Plot graph to verify that the class distribution in train is the same as in the original data.
train.pivot_table(index='label_encd', aggfunc='size').plot(kind='bar', title='Verify that class distributuion in train is same as input data')
# Out:
# <Axes: title={'center': 'Verify that class distributuion in train is same as input data'}, xlabel='label_encd'>

# %%
# Also check whether the stratification went well in the test data.
test.pivot_table(index='label_encd', aggfunc='size').plot(kind='bar', title='Verify that class distributuion in test is same as input data')
# Out:
# <Axes: title={'center': 'Verify that class distributuion in test is same as input data'}, xlabel='label_encd'>

# %% [markdown]
# ## Model Training

# %% [markdown]
# #### First building a Logistic Regression model on the original data

# %%
# Training the classifier
from sklearn.linear_model import LogisticRegression
log_reg = LogisticRegression()

# Fit the logistic regression on the independent variables of the train data with label_encd as dependent variable
log_reg.fit(train[['lemmatized_encd']], train['label_encd'])

# Make a prediction using our model on the test set
log_reg_pred = log_reg.predict(test[['lemmatized_encd']])

# %%
# Evaluate the predictive performance by looking at the confusion matrix
from sklearn.metrics import confusion_matrix
tn, fp, fn, tp = confusion_matrix(test['label_encd'], log_reg_pred).ravel()
print('True negatives: ', tn, '\nFalse positives: ', fp, '\nFalse negatives: ', fn, '\nTrue Positives: ', tp)
# Out:
# True negatives:  241
# False positives:  0
# False negatives:  34
# True Positives:  0

# %%
# View the classification report
from sklearn.metrics import classification_report
print(classification_report(test['label_encd'], log_reg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93       241
#            1       0.00      0.00      0.00        34
#
#     accuracy                           0.88       275
#    macro avg       0.44      0.50      0.47       275
# weighted avg       0.77      0.88      0.82       275

# %% [markdown]
# #### Use the SMOTE package to balance data

# %%
# transform the dataset
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 42)
X_res, y_res = sm.fit_resample(train[['lemmatized_encd']], train['label_encd'])

# %%
# verify the data is balanced
pd.Series(y_res).value_counts().plot(kind='bar', title='Class distribution after appying SMOTE', xlabel='label_encd')
# Out:
# <Axes: title={'center': 'Class distribution after appying SMOTE'}, xlabel='label_encd'>

# %% [markdown]
# #### Logistic Regression classifier

# %%
#Tunning parameters
params = {
    'penalty' : ['l1','l2'], 
    'C'       : np.logspace(-3,3,7),
    'solver'  : ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
}

lrc = LogisticRegression()
model = GridSearchCV(estimator = lrc, param_grid = params,  cv = 10)
model.fit(X_res, y_res)

print("Best: %f using %s" % (model.best_score_, model.best_params_))
# Out:
# Best: 0.571176 using {'C': 0.001, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
#Training the model
lrc = LogisticRegression(solver='liblinear', penalty='l2', C=1.0)
lrc.fit(X_res, y_res)

# evaluating the classifier
lrc_y_pred = lrc.predict(test[['lemmatized_encd']])

# looking at the confusion matrix
#tn, fp, fn, tp = confusion_matrix(test['label_encd'], lrc_y_pred).ravel()
#print('True negatives: ', tn, '\nFalse positives: ', fp, '\nFalse negatives: ', fn, '\nTrue positives: ', tp)

# %%
# the classification report
print(classification_report(test['label_encd'], lrc_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.58      0.70       241
#            1       0.14      0.50      0.22        34
#
#     accuracy                           0.57       275
#    macro avg       0.52      0.54      0.46       275
# weighted avg       0.80      0.57      0.64       275

# %% [markdown]
# #### Random forest classifier.

# %%
#Tunning parameters
from sklearn.ensemble import RandomForestClassifier

params = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

rfc = RandomForestClassifier(random_state=42)
model = GridSearchCV(estimator = rfc, param_grid = params,  cv = 5)
model.fit(X_res, y_res)

print("Best: %f using %s" % (model.best_score_, model.best_params_))
# Out:
# Best: 0.837171 using {'criterion': 'entropy', 'max_depth': 6, 'max_features': 'auto', 'n_estimators': 500}

# %%
# Training the classifier
rfc = RandomForestClassifier(random_state=42, criterion='entropy', max_depth=8, max_features='auto', n_estimators= 200)
rfc.fit(X_res, y_res)

# evaluating the classifier
rfc_y_pred = rfc.predict(test[['lemmatized_encd']])

# the confusion matrix
#tn, fp, fn, tp = confusion_matrix(test['label_encd'], rfc_y_pred).ravel()
#print('True negatives: ', tn, '\nFalse positives: ', fp, '\nFalse negatives: ', fn, '\nTrue positives: ', tp)

# %%
# the classification report
print(classification_report(test['label_encd'], rfc_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.83      0.88       241
#            1       0.34      0.62      0.44        34
#
#     accuracy                           0.80       275
#    macro avg       0.64      0.72      0.66       275
# weighted avg       0.86      0.80      0.83       275

# %% [markdown]
# #### KNN classifier

# %%
#Tunning parameters
from sklearn.neighbors import KNeighborsClassifier
params = {'n_neighbors' : list(range(1, 21)),
          'weights' : ['uniform','distance'],
          'metric' : ['minkowski','euclidean','manhattan']}

knn = KNeighborsClassifier()
model = GridSearchCV(estimator = knn, param_grid = params, verbose = 1, cv=3, n_jobs = -1)
model.fit(X_res, y_res)

print("Best: %f using %s" % (model.best_score_, model.best_params_))
# Out:
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# Best: 0.826488 using {'metric': 'minkowski', 'n_neighbors': 8, 'weights': 'uniform'}

# %%
# Training the classifier
knn = KNeighborsClassifier(n_neighbors=7, metric='minkowski', weights='uniform', algorithm='auto') 
knn.fit(X_res,y_res)

# evaluating the classifier
knn_y_pred = knn.predict(test[['lemmatized_encd']])

# the confusion matrix
#tn, fp, fn, tp = confusion_matrix(test['label_encd'], knn_y_pred).ravel()
#print('True negatives: ', tn, '\nFalse positives: ', fp, '\nFalse negatives: ', fn, '\nTrue positives: ', tp)

# %%
# the classification report
print(classification_report(test['label_encd'], knn_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89       241
#            1       0.36      0.62      0.45        34
#
#     accuracy                           0.81       275
#    macro avg       0.65      0.73      0.67       275
# weighted avg       0.87      0.81      0.83       275

# %% [markdown]
# #### SVM Model

# %%
#Tunning parameters
from sklearn.svm import SVC
params = {'C': [0.1, 1, 10, 100, 1000], 
          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
          'kernel': ['rbf', 'poly', 'sigmoid']}

svc = SVC()
#model = GridSearchCV(estimator = svc, param_grid = params, refit = True, verbose = 1)
#model.fit(X_res, y_res)

#print("Best: %f using %s" % (model.best_score_, model.best_params_))
#print("Estimator: %s" % (grid.best_estimator_))

# %%
# Training the classifier
svc = SVC(probability=False, kernel='rbf', gamma=0.1, C=1)
svc.fit(X_res, y_res)

# evaluating the classifier
svc_y_pred = svc.predict(test[['lemmatized_encd']])

# the confusion matrix
#tn, fp, fn, tp = confusion_matrix(test['label_encd'], svc_y_pred).ravel()
#print('True negatives: ', tn, '\nFalse positives: ', fp, '\nFalse negatives: ', fn, '\nTrue positives: ', tp)

# %%
# the classification report
print(classification_report(test['label_encd'], svc_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.85      0.90       241
#            1       0.38      0.65      0.48        34
#
#     accuracy                           0.83       275
#    macro avg       0.66      0.75      0.69       275
# weighted avg       0.87      0.83      0.84       275

# %% [markdown]
# #### XGBoost Classifier

# %%
#Tunning parameters
from xgboost import XGBClassifier

# A parameter grid for XGBoost
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }

eval_set = [(X_res, y_res)]

estimator = XGBClassifier()

model = GridSearchCV(estimator=estimator, param_grid=params, cv=3, scoring="neg_log_loss")

model.fit(X_res, y_res, eval_set=eval_set, verbose=0)

print("Best: %f using %s" % (model.best_score_, model.best_params_))
# Out:
# Best: -0.402729 using {'colsample_bytree': 0.6, 'gamma': 2, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6}

# %%
# Training the classifier
xgb = XGBClassifier(colsample_bytree=0.6, gamma=2, max_depth=5, min_child_weight=1, subsample=0.6)
xgb.fit(X_res, y_res)

# evaluating the classifier
xgb_y_pred = xgb.predict(test[['lemmatized_encd']])

# the confusion matrix
#tn, fp, fn, tp = confusion_matrix(test['label_encd'], xgb_y_pred).ravel()
#print('True negatives: ', tn, '\nFalse positives: ', fp, '\nFalse negatives: ', fn, '\nTrue positives: ', tp)

# %%
# the classification report
print(classification_report(test['label_encd'], xgb_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87       241
#            1       0.32      0.59      0.41        34
#
#     accuracy                           0.79       275
#    macro avg       0.63      0.70      0.64       275
# weighted avg       0.86      0.79      0.82       275

# %% [markdown]
# #### AdaBoost Classifier

# %%
# define the grid of values to search
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import RepeatedStratifiedKFold

params = {
    'n_estimators' : [10, 50, 100, 500], 
    'learning_rate'  : [0.0001, 0.001, 0.01, 0.1, 1.0]
}

# define the evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# define the grid search procedure
grid_search = GridSearchCV(AdaBoostClassifier(), param_grid=params, n_jobs=-1, cv=cv, scoring='accuracy')

# execute the grid search
grid_result = grid_search.fit(X_res, y_res)

# summarize the best score and configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.829227 using {'learning_rate': 1.0, 'n_estimators': 500}

# %%
# Training the classifier
abc = AdaBoostClassifier(n_estimators=500, learning_rate=1.0)
abc.fit(X_res, y_res)

# evaluating the classifier
abc_y_pred = abc.predict(test[['lemmatized_encd']])

# the confusion matrix
#tn, fp, fn, tp = confusion_matrix(test['label_encd'], abc_y_pred).ravel()
#print('True negatives: ', tn, '\nFalse positives: ', fp, '\nFalse negatives: ', fn, '\nTrue positives: ', tp)

# %%
# the classification report
print(classification_report(test['label_encd'], abc_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.83      0.88       241
#            1       0.35      0.68      0.46        34
#
#     accuracy                           0.81       275
#    macro avg       0.65      0.75      0.67       275
# weighted avg       0.87      0.81      0.83       275

# %% [markdown]
# ### AUC Curve

# %%
import sklearn.metrics as metrics

fpr, tpr, _ = metrics.roc_curve(test,  lrc_y_pred)
auc = round(metrics.roc_auc_score(test, lrc_y_pred), 4)
plt.plot(fpr,tpr,label="Logistic Regression, AUC="+str(auc))

fpr, tpr, _ = metrics.roc_curve(test,  rfc_y_pred)
auc = round(metrics.roc_auc_score(test, rfc_y_pred), 4)
plt.plot(fpr,tpr,label="Random Forest, AUC="+str(auc))

fpr, tpr, _ = metrics.roc_curve(test,  knn_y_pred)
auc = round(metrics.roc_auc_score(test, knn_y_pred), 4)
plt.plot(fpr,tpr,label="K-Nearest Neighbor, AUC="+str(auc))

fpr, tpr, _ = metrics.roc_curve(test,  svc_y_pred)
auc = round(metrics.roc_auc_score(test, svc_y_pred), 4)
plt.plot(fpr,tpr,label="SVM, AUC="+str(auc))

fpr, tpr, _ = metrics.roc_curve(test,  xgb_y_pred)
auc = round(metrics.roc_auc_score(test, xgb_y_pred), 4)
plt.plot(fpr,tpr,label="XGBoost, AUC="+str(auc))

fpr, tpr, _ = metrics.roc_curve(test,  abc_y_pred)
auc = round(metrics.roc_auc_score(test, abc_y_pred), 4)
plt.plot(fpr,tpr,label="AdaBoost, AUC="+str(auc))



#create ROC curve
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
#plt.show()

#add legend
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 import sklearn.metrics as metrics
# ----> 3 fpr, tpr, _ = metrics.roc_curve(test,  lrc_y_pred)
#       4 auc = round(metrics.roc_auc_score(test, lrc_y_pred), 4)
#       5 plt.plot(fpr,tpr,label="Logistic Regression, AUC="+str(auc))
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:992, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     904 def roc_curve(
#     905     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#     906 ):
#     907     """Compute Receiver operating characteristic (ROC).
#     908
#     909     Note: this implementation is restricted to the binary classification task.
#    (...)
#     990     array([1.8 , 0.8 , 0.4 , 0.35, 0.1 ])
#     991     """
# --> 992     fps, tps, thresholds = _binary_clf_curve(
#     993         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     994     )
#     996     # Attempt to drop thresholds corresponding to points in between and
#     997     # collinear with other points. These are always suboptimal and do not
#     998     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1003     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1004     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1005     if drop_intermediate and len(fps) > 2:
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:747, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     713 """Calculate true and false positives per binary classification threshold.
#     714
#     715 Parameters
#    (...)
#     744     Decreasing score values.
#     745 """
#     746 # Check to make sure y_true is valid
# --> 747 y_type = type_of_target(y_true, input_name="y_true")
#     748 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     749     raise ValueError("{0} format is not supported".format(y_type))
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/multiclass.py:298, in type_of_target(y, input_name)
#     295 if sparse_pandas:
#     296     raise ValueError("y cannot be class 'SparseSeries' or 'SparseArray'")
# --> 298 if is_multilabel(y):
#     299     return "multilabel-indicator"
#     301 # DeprecationWarning will be replaced by ValueError, see NEP 34
#     302 # https://numpy.org/neps/nep-0034-infer-dtype-is-object.html
#     303 # We therefore catch both deprecation (NumPy < 1.24) warning and
#     304 # value error (NumPy >= 1.24).
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/multiclass.py:180, in is_multilabel(y)
#     174     return (
#     175         len(y.data) == 0
#     176         or (labels.size == 1 or (labels.size == 2) and (0 in labels))
#     177         and (y.dtype.kind in "biu" or _is_integral_float(labels))  # bool, int, uint
#     178     )
#     179 else:
# --> 180     labels = xp.unique_values(y)
#     182     return len(labels) < 3 and (
#     183         y.dtype.kind in "biu" or _is_integral_float(labels)  # bool, int, uint
#     184     )
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/_array_api.py:84, in _NumPyApiWrapper.unique_values(self, x)
#      83 def unique_values(self, x):
# ---> 84     return numpy.unique(x)
#
# File <__array_function__ internals>:180, in unique(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'int' and 'str'
